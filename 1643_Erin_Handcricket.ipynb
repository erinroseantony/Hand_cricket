# %%
def user_bat():
    import random
    score=0
    while True:
        a=int(input('enter a number from 1 to 6:' ))
        l=[1,2,3,4,5,6]
        b=random.choice(l)
        if a!=b:
            score+=a
        else:
            print('OUT')
            break
    print("user's score:",score)
    score1=0
    while True:
        c=int(input('enter a number from 1 to 6: '))
        l1=[1,2,3,4,5,6]
        d=random.choice(l1)
        if a!=d:
            score1+=d
        else:
            print('OUT')
            break
    print("computer's score",score1)
    if(score>score1):
        print(f'User won the match by {score-score1} runs')
    elif (score==score1):
        print('Match Tie!')
    else:
        print(f'Computer won the match by {score1-score} runs')


def user_bwol():
    import random
    score=0
    while True:
        a=int(input('enter a number from 1 to 6:' ))
        l=[1,2,3,4,5,6]
        b=random.choice(l)
        if a!=b:
            score+=a
        else:
            print('OUT')
            break
    print("Computer's score:",score)
    score1=0
    while True:
        c=int(input('enter a number from 1 to 6: '))
        l1=[1,2,3,4,5,6]
        d=random.choice(l1)
        if a!=d:
            score1+=d
        else:
            print('OUT')
            break
    print("User's score",score1)
    if(score>score1):
        print(f'Computer won the match by {score-score1} runs')
    elif (score==score1):
        print('Match Tie!')
    else:
        print(f'User won the match by {score1-score} runs')

def computer_bat():
    import random
    score=0
    while True:
        a=int(input("Enter a Number from 1 to 6:"))
        l=[1,2,3,4,5,6]
        b=random.choice(l)
        if a!=b:
            score+=b
        else:
            print("OUT")
            break
    print("Computer's Score:",score)
    score1=0
    while True:
        c=int(input("Enter a Number from 1 to 6:"))
        l1=[1,2,3,4,5,6]
        d=random.choice(l1)
        if c!=d:
            score1+=c5
        else:
            print("OUT!!!")
            break
    print("User's Score:",score1)
    if(score>score1):
        print(f"Computer Won the Match by {score-score1} runs")
    elif(score==score1):
        print("Match TIE!!!")
    else:
        print(f"User Won the Match by {score1-score} runs")

def computer_bowl():
    import random
    score=0
    while True:
        a=int(input("Enter a Number from 1 to 6:"))
        l=[1,2,3,4,5,6]
        b=random.choice(l)
        if a!=b:
            score+=a
        else:
            print("OUT!!!")
            break
    print("User's Score:",score)
    score1=0
    while True:
        c=int(input("Enter a Number from 1 to 6:"))
        l1=[1,2,3,4,5,6]
        d=random.choice(l1)
        if c!=d:
            score1+=d
        else:
            print("OUT!!!")
            break
    print("Computer's Score:",score1)
    if(score>score1):
        print(f"User Won the Match by {score-score1} runs")
    elif(score==score1):
        print("Match TIE!!!")
    else:
        print(f"Computer Won the Match by {score1-score} runs")


print('\t\t\t WELCOME TO HAND CRICKET')
print('choose an option:   \n\t\t1.even \n\t\t2.odd')
a=int(input('enter your choice:'))
b=int(input('enter a number:'))
import random
c=[1,2,3,4,5,6,7,8,9]
d=random.choice(c)
print(f'computer choose: {d}')

if ((b+d)%2==0 and a==1):
    print('User won the toss')
    print('choose bat or bwol')
    e=str(input('enter your choice:'))
    print(f'user choose : {e}')
    if(e=='bat'):
        user_bat()
    else:
        user_bwol()
elif ((b+d)%2==0 and a!=1):
    f=['bat', 'bwol']
    el=random.choice(f)
    print('Computer won the toss')
    print(f'computer choose : {el}')
    if(el=='bat'):
        computer_bat()
    else:
        computer_bwol()
elif((b+d)%2!=0 and a==2):
    print('User won the toss')
    print('choose bat or bwol')
    e=str(input('enter your choice:'))
    print(f'user choose : {e}')
    if(e=='bat'):
        user_bat()
    else:
        user_bwol()
else:
    i=['bat','bwol']
    el=random.choice(i)
    print('Computer won the toss')
    print(f'computer choose : {el}')
    if(el=='bat'):
        computer_bat()
    else:
        computer_bwol()
# Out:
# 			 WELCOME TO HAND CRICKET
# choose an option:
# 		1.even
# 		2.odd
# enter your choice: 1
# enter a number: 3
# computer choose: 7
# User won the toss
# choose bat or bwol
# enter your choice: bwol
# user choose : bwol
# enter a number from 1 to 6: 4
# enter a number from 1 to 6: 3
# enter a number from 1 to 6: 6
# enter a number from 1 to 6: 5
# enter a number from 1 to 6: 2
# enter a number from 1 to 6: 3
# enter a number from 1 to 6: 4
# enter a number from 1 to 6: 2
# enter a number from 1 to 6: 5
# enter a number from 1 to 6: 1
# enter a number from 1 to 6: 4
# enter a number from 1 to 6: 4
# enter a number from 1 to 6: 2
# enter a number from 1 to 6: 3
# enter a number from 1 to 6: 1
# enter a number from 1 to 6: 5
# enter a number from 1 to 6: 5
# enter a number from 1 to 6: 5
# enter a number from 1 to 6: 2
# enter a number from 1 to 6: 2
# enter a number from 1 to 6: 4
# enter a number from 1 to 6: 5
# enter a number from 1 to 6: 4
# enter a number from 1 to 6: 5
# ...

# %% [markdown]
# #
